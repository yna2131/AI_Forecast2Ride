# %% [markdown]
# # Pre-processing Data / Pre-EDA

# %%
import pandas as pd
from random import sample

# %%
combinedData = pd.read_csv("SeoulBikeData.csv")

trainingData = combinedData.sample(frac=0.8, replace=False)

trainingData.to_csv("TrainingData.csv")
trainingData.head()
# Out:
#             Date  Rented Bike Count  Hour  Temperature(C)  Humidity(%)  \
# 3919  13/05/2018                220     7            13.7           98
# 7273  30/09/2018                  0     1            17.5           66
# 3531  27/04/2018                258     3            10.7           63
# 5048  29/06/2018               2028     8            22.2           95
# 3586  29/04/2018                787    10            17.5           35
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(C)  \
# 3919               1.6               468                      13.3
# 7273               0.5              2000                      11.0
# 3531               1.1               989                       3.9
# 5048               1.6               389                      21.3
# 3586               1.8              1570                       1.8
#
#       Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons  \
# 3919                     0.10           0.0            0.0  Spring
# 7273                     0.00           0.0            0.0  Autumn
# 3531                     0.00           0.0            0.0  Spring
# 5048                     0.26           0.0            0.0  Summer
# 3586                     2.26           0.0            0.0  Spring
#
#          Holiday Functioning Day
# 3919  No Holiday             Yes
# 7273  No Holiday              No
# 3531  No Holiday             Yes
# 5048  No Holiday             Yes
# 3586  No Holiday             Yes
